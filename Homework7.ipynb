# %% [markdown]
# ## W7A16
# Cho một mảng số nguyên không âm. Gọi mảng đó là "mảng đẹp" nếu
# mỗi phần tử x trong mảng xuất hiện đúng x lần.
# Kiểm tra xem mảng có phải là mảng đẹp hay không. Nếu không hãy xóa
# đi y số (y là nhỏ nhất có thể) để mảng còn lại thành mảng đẹp.

# %%
def kiem_tra_mang_dep(arr):
    counts = {}
    for x in arr:
        if x in counts:
            counts[x] += 1
        else:
            counts[x] = 1         
    y = 0 
    for x in counts:
        c = counts[x]
        if x == 0:
            y += c    
        elif c < x:
            y += c   
        else:
            y += (c - x)
    if y == 0:
        print("Mảng đã cho là mảng đẹp!")
    else:
        print("Mảng không phải là mảng đẹp.")
        print("Số lượng số cần xóa ít nhất là:", y)
        
    return y
mang_1 = [3, 1, 3, 2, 3, 2]
kiem_tra_mang_dep(mang_1)

# %% [markdown]
# ## W7A17
# Tìm phần tử xuất hiện nhiều hơn n/2 lần trong mảng (nếu có) với độ
# phức tạp thời gian là O(n), độ phức tạp bộ nhớ là O(1), - Boyer–Moore.
# Nếu không có phần tử nào thỏa mãn thì không in gì

# %%
def find_majority_element(arr):
    n = len(arr)
    if n == 0:
        return
    candidate = None
    count = 0
    
    for x in arr:
        if count == 0:
            candidate = x
            count = 1
        elif x == candidate:
            count += 1
        else:
            count -= 1
    actual_count = 0
    for x in arr:
        if x == candidate:
            actual_count += 1
    if actual_count > n // 2:
        print(candidate)
    else:
        pass

print("Kết quả test 1: ", end="")
arr1 = [2, 2, 1, 1, 2, 3, 2]
find_majority_element(arr1)

# %% [markdown]
# ## W7A18
# Sắp xếp có điều kiện: Số chẵn đứng trước, số lẻ đứng sau, chẵn tăng
# dần, lẻ giảm dần; ;

# %%
def sap_xep_co_dieu_kien(arr):
    chan = []
    le = []
    for x in arr:
        if x % 2 == 0:
            chan.append(x)
        else:
            le.append(x)
    chan.sort()               
    le.sort(reverse=True)     
    
    ket_qua = chan + le
    return ket_qua

mang_ban_dau = [5, 2, 9, 1, 6, 4, 8, 3, 7, 0]
print("Mảng ban đầu:", mang_ban_dau)
print("Sau khi sắp xếp:", sap_xep_co_dieu_kien(mang_ban_dau))
# Out:
# Mảng ban đầu: [5, 2, 9, 1, 6, 4, 8, 3, 7, 0]
# Sau khi sắp xếp: [0, 2, 4, 6, 8, 9, 7, 5, 3, 1]

# %% [markdown]
# ## W7A19
# Merge 2 mảng đã sắp xếp (có thể tăng dần, có thể giảm dần) mà không
# dùng bất cứ thuật toán sắp xếp nào

# %%
def merge(l1,l2):
    i = j = 0
    res = []
    if len(l1) == 0 or len(l2) == 0:
        return l1 + l2
    if l1[0] < l1[-1]:
        while i < len(l1) and j < len(l2):
            if l1[i] < l2[j]:
                res.append(l1[i])
                i += 1
            else:
                res.append(l2[j])
                j += 1
    else:
        while i < len(l1) and j < len(l2):
            if l1[i] > l2[j]: 
                res.append(l1[i])
                i += 1
            else:
                res.append(l2[j])
                j += 1
    while i < len(l1):
        res.append(l1[i])
        i += 1
    while j < len(l2):
        res.append(l2[j])
        j += 1
    return res
l1 = [1, 2, 4, 6, 7, 87]
l2 = [1, 3, 5, 5, 9, 45, 66]

print(*merge(l1, l2))
# Out:
# 1 1 2 3 4 5 5 6 7 9 45 66 87

# %% [markdown]
# ## W7A20
# Cho dãy N số nguyên dương, tính tổng các số có k chữ số. Dòng đầu ghi
# N số nguyên dương, dòng sau ghi số nguyên dương k

# %%
day_so = input().split()

k = int(input("Nhập số chữ số k: "))

tong = 0
for so_chuoi in day_so:
    if len(so_chuoi) == k:
        tong += int(so_chuoi) 

print("Tổng các số có", k, "chữ số là:", tong)
# Out:
# Tổng các số có 2 chữ số là: 49
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## W7A21
# Cho N là ngày, T là tháng năm 2020, Tính xem đó là ngày thứ bao nhiêu
# của năm đó nếu đó là ngảy hợp lệ

# %%
N = int(input("Nhập ngày N: "))
T = int(input("Nhập tháng T: "))

so_ngay_thang = [0, 31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

# Kiểm tra xem tháng và ngày nhập vào có hợp lệ không
if T < 1 or T > 12 or N < 1 or N > so_ngay_thang[T]:
    print("Ngày không hợp lệ")
else:
    tong_ngay = sum(so_ngay_thang[1:T]) + N
    print(f"Đó là ngày thứ {tong_ngay} của năm 2020")
# Out:
# Đó là ngày thứ 60 của năm 2020

# %% [markdown]
# ## W7A22
# Cho N tên sinh viên gồm cả họ và tên, tìm xem tên nào hay gặp nhất.
# Nếu có nhiều tên cùng số lần gặp thì lấy tên có thứ tự từ điển nhỏ nhất

# %%
def tim_ten_pho_bien_nhat(danh_sach_ten):
    if not danh_sach_ten:
        return None
        
    dem_ten = {}
    for ten in danh_sach_ten:
        if ten in dem_ten:
            dem_ten[ten] += 1
        else:
            dem_ten[ten] = 1
    best_name = None
    max_count = -1
    
    for ten in dem_ten:
        count = dem_ten[ten]
        
        if count > max_count:
            max_count = count
            best_name = ten
            
        elif count == max_count:
            if ten < best_name:
                best_name = ten
                
    return best_name

ds1 = ["Nguyen Van A", "Tran Thi B", "Nguyen Van A", "Le Van C"]
print(tim_ten_pho_bien_nhat(ds1))
# Out:
# Nguyen Van A

# %% [markdown]
# ## W7A23
# Đếm số lượng tên trong xâu kí tự. Tên được định nghĩa là xâu có độ dài
# '>=2' và có chữ cái đầu viết hoa, các chữ cái khác viết thường, chỉ có kí
# tự cái.

# %%
def dem_ten(xau):
    cac_tu = xau.split()
    dem = 0
    
    for tu in cac_tu:
        if len(tu) >= 2 and tu.isalpha() and tu[0].isupper() and tu[1:].islower():
            dem = dem + 1
            
    return dem

xau_mau = "Nguyen Van A di xe may nhan hieu Honda"
print(dem_ten(xau_mau))
# Out:
# 3

# %% [markdown]
# ## W7A24
# Cho xâu kí tự, xóa các **từ** giống nhau liền kề, chỉ giữ lại từ đầu tiên

# %%
def xoa_tu_lien_ke(s):
    words = s.split()
    if not words:
        return ""
    
    result = words[0]
    
    for i in range(1, len(words)):
        if words[i] != words[i-1]:
            result = result + " " + words[i]
            
    return result

xau_goc = "học học nữa nữa mãi mãi học"
xau_moi = xoa_tu_lien_ke(xau_goc)

print("Xâu gốc:", xau_goc)
print("Xâu sau khi xóa:", xau_moi)
# Out:
# Xâu gốc: học học nữa nữa mãi mãi học
# Xâu sau khi xóa: học nữa mãi học

# %% [markdown]
# ## W7A25
# Tìm số có đúng k chữ số lớn nhất có thể trong một số có n chữ số (coi
# đầu vào là một số rất lớn - str). Không được hoán đổi vị trí các chữ số

# %%
def tim_so_lon_nhat(s, k):
    n = len(s)
    so_lan_xoa = n - k 
    hop = []
    
    for x in s:
        while len(hop) > 0 and so_lan_xoa > 0 and hop[-1] < x:
            hop.pop()  
            so_lan_xoa = so_lan_xoa - 1
            
        hop.append(x)   
        
    ket_qua = hop[:k]
    return "".join(ket_qua)

print("Số lớn nhất thu được:", tim_so_lon_nhat("14329", 3))
# Out:
# Số lớn nhất thu được: 439

# %% [markdown]
# ## W7A26
# Tách các số có trong một đoạn văn bản, tính tổng và tính trung bình các
# số đó.

# %%
def sum_str(s):
    res = []
    c = 0
    so = '0123456789'
    for i in range(len(s)):
        if s[i] in so:
            res.append(int(s[i]))
            c += 1
    return sum(res)/c
s = input()
print(sum_str(s))
# Out:
# 2.0

# %% [markdown]
# ## W7A27
# Cho một dãy ngoặc ()(){}{}[][]..., kiểm tra xem dãy ngoặc đã cho có hợp lệ
# hay không

# %%
def kiem_tra_ngoac(chuoi):
    hop = [] 
    for ngoac in chuoi:
        # Nếu gặp dấu mở, bỏ vào hộp
        if ngoac == "(" or ngoac == "[" or ngoac == "{":
            hop.append(ngoac)
        # Nếu gặp dấu đóng, kiểm tra xem dấu mở cuối cùng trong hộp có khớp không
        elif ngoac == ")":
            if len(hop) == 0 or hop[-1] != "(":
                return False
            hop.pop()       
        elif ngoac == "]":
            if len(hop) == 0 or hop[-1] != "[":
                return False
            hop.pop()  
        elif ngoac == "}":
            if len(hop) == 0 or hop[-1] != "{":
                return False
            hop.pop()
            
    return len(hop) == 0

print(kiem_tra_ngoac("([])"))  
print(kiem_tra_ngoac("([)]"))
# Out:
# True
# False

# %% [markdown]
# ## W7A28
# Bài toán Tìm dãy các hợp số dài nhất liên tiếp không chứa số nguyên
# nào <= N (N là số nguyên dương cho trước). Nếu có nhiều dãy cùng độ
# dài thì lấy dãy nhỏ nhất (gặp đầu tiên từ trái qua)

# %%
def la_so_nguyen_to(x):
    if x < 2:
        return False
    for i in range(2, int(x**0.5) + 1):
        if x % i == 0:
            return False
    return True

def tim_day_hop_so(N):
    dai_max = 0
    dau_max = -1
    dai = 0
    dau = -1
    
    for x in range(2, N + 1):
        if la_so_nguyen_to(x) == False:
            if dai == 0:
                dau = x  
            dai = dai + 1
            
        else:
            if dai > dai_max:
                dai_max = dai
                dau_max = dau
            dai = 0  
    if dai > dai_max:
        dai_max = dai
        dau_max = dau
    ket_qua = []
    if dai_max > 0:
        for i in range(dau_max, dau_max + dai_max):
            ket_qua.append(i)
            
    return ket_qua

print(tim_day_hop_so(30))
# Out:
# [24, 25, 26, 27, 28]

# %% [markdown]
# ## W7A29
# Tìm Dãy con tăng dần liên tục dài nhất của một danh sách nhập vào từ
# bàn phím. Lấy dãy đầu tiên nếu có nhiều dãy có số phần tử bằng nhau

# %%
a = [int(x) for x in input("Nhập danh sách: ").split()]

if not a:
    print("Danh sách rỗng")
else:
    dai_max = 1
    dau_max = 0 
    
    dai = 1
    dau = 0     
    
    for i in range(1, len(a)):
        if a[i] > a[i-1]:
            dai = dai + 1
        else:
            if dai > dai_max:
                dai_max = dai
                dau_max = dau
            dai = 1
            dau = i  
    if dai > dai_max:
        dai_max = dai
        dau_max = dau
    ket_qua = a[dau_max : dau_max + dai_max]
    print("Dãy con tăng liên tục dài nhất:", ket_qua)

# %% [markdown]
# ## W7A30
# Tìm Dãy con tăng dần KHÔNG liên tục dài nhất của một danh sách nhập
# vào từ bàn phím

# %%
a = [int(x) for x in input("Nhập danh sách: ").split()]

if not a:
    print("Danh sách rỗng")
else:
    n = len(a)
    L = [1] * n 
    P = [-1] * n 
    
    for i in range(1, n):
        for j in range(0, i):
            if a[i] > a[j] and L[i] < L[j] + 1:
                L[i] = L[j] + 1
                P[i] = j  
    dai_max = max(L)
    vi_tri_max = L.index(dai_max)
    ket_qua = []
    curr = vi_tri_max
    while curr != -1:
        ket_qua.append(a[curr])
        curr = P[curr]
        
    ket_qua.reverse()
    
    print("Dãy con tăng không liên tục dài nhất:", ket_qua)
# Out:
# Dãy con tăng không liên tục dài nhất: [1, 2, 5, 12, 44, 55]
