# %% [markdown]
# ## W6A1
# Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng
# giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.
# Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
ds = list(map(int, input().split()))
ds_new = []
for i in ds:
    if i not in ds_new:
        ds_new.append(i)
print(ds_new)
# Out:
# [2, 1, 3, 5, 4]

# %% [markdown]
# ## W6A2
# Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị trí i), giữ nguyên thứ tự

# %%
def list_ttl(a):
    tong_tich_luy = []
    tong_phan_tu = 0
    for i in a:
        tong_phan_tu += i
        tong_tich_luy.append(tong_phan_tu)
    return tong_tich_luy
n = list(map(int, input().split()))
list_ttl(n)
# Out:
# [1, 4, 9, 15]

# %% [markdown]
# ## W6A3
# Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple
# sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp
# xếp.)

# %%
t = tuple(map(int, input().split()))
k = int(input())
n = len(t)
if n > 0:
    k = k % n
    ket_qua = t[k:] + t[:k]
    print(ket_qua)
else:
    print(t)
# Out:
# (1,)

# %% [markdown]
# ## W6A4
# Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo
# dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp lại, thêm vào list của key đó

# %%
#cách 1
dic = {}
n = input().split()
for i in n:
    p = i.split(":")
    k = p[0]
    v = p[1]
    if k in dic:
        dic[k].append(v)
    else:
        dic[k] = [v]
print(dic)
# Out:
# {'k': ['deptrai', 'cute'], 'a': ['1'], 'b': ['2']}

# %%
#cách 2
dic = {}
n = input().split()
for i in n:
    k,v = i.split(":")
    if k not in dic:
        dic[k] = []
    dic[k].append(v)
print(dic)
# Out:
# {'kien': ['deptrai', 'cute'], 'a': ['1'], 'b': ['2']}

# %% [markdown]
# ## W6A5
# Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ..., 'zeros': ...} (đếm số >0, <0, =0)

# %%
dic = {'positives': 0, 'negatives': 0, 'zeros': 0}
n = list(map(int, input().split()))
for i in n:
    if i < 0:
        dic['positives'] += 1
    elif i == 0:
        dic['zeros'] += 1
    else:
        dic['negatives'] += 1
print(dic)
# Out:
# {'positives': 2, 'negatives': 2, 'zeros': 1}

# %% [markdown]
# ## W6A6
# Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số trong list đó.

# %%
n = list(map(int, input().split()))  
tong = 0 
dem = 0
for i in n:
    tong += i
    dem += 1  
print(tong/dem)
# Out:
# 2.6

# %% [markdown]
# ## W6A7
# Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo ngược.

# %%
n = tuple(map(int, input().split()))
print(n[0],n[-1],n[::-1])
# Out:
# 1 5 (5, 4, 3, 2, 1)

# %% [markdown]
# ## W6A8
# Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng chuỗi và lưu vào dictionary.

# %%
lst = list(map(int, input().split()))
d = {}
for i in lst:
    if i in d:
        d[i] += 1
    else:
        d[i] = 1
print(d)
# Out:
# {1: 2, 2: 1, 3: 2, 4: 3}

# %% [markdown]
# ## W6A9
# Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một dictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ
# được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của key.

# %%
def nhap_dict():
    d = {}
    n = int(input())
    for i in range(n):
        k = input()
        v = int(input())
        d[k] = v
    return d
d1 = nhap_dict()
d2 = nhap_dict()
kq = {}
for k in d1:
    kq[k] = d1[k]
for k in d2:
    if k in kq:
        kq[k] += d2[k]
    else:
        kq[k] = d2[k]
danh_sach_ten = sorted(kq.keys())
ket_qua_cuoi = {}
for k in danh_sach_ten:
    ket_qua_cuoi[k] = kq[k]

print(ket_qua_cuoi)
# Out:
# {'j': 1, 'k': 5, 'l': 3}

# %% [markdown]
# ## W6A10
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên
# dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là
# một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh
# sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được
# sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
n = list(map(int, input().split()))
k = int(input())
kq = []
for i in range(len(n)):
    for j in range(i + 1, len(n)):
        if n[i] + n[j] == k:
            kq.append((n[i], n[j]))
kq.sort()
print(kq)
# Out:
# [(1, 7), (2, 6), (3, 5)]

# %% [markdown]
# ## W6A11 [Tách số chẵn và lẻ từ tuple]
# Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
t = tuple(map(int, input().split()))
l_le = []
l_chan = []
for x in t:
    if x % 2 == 0: 
        l_chan.append(x)
    else:               
        l_le.append(x)
t_le = tuple(l_le)
t_chan = tuple(l_chan)
print(t_chan)
print(t_le)
# Out:
# (2, 4, 6, 8)
# (1, 3, 5, 7)

# %% [markdown]
# ## W6A12 [Tìm phần tử xuất hiện nhiều nhất]
# Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất trong số đó.

# %%
n = list(map(int, input().split()))
d = {}
for x in n:
    if x in d:
        d[x] += 1
    else:
        d[x] = 1
a = 0
for x in d:
    if d[x] > a:
        a = d[x]
lst = []
for x in d:
    if d[x] == a:
        lst.append(x)
print(min(lst))

# %% [markdown]
# ## W6A13 [Đảo ngược key và value của dictionary]
# Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạomột dictionary mới bằng cách đảo ngược key và value của dictionary ban
# đầu. In ra dictionary mới.

# %%
def nhap_dictionary():
    d = {}
    n = int(input())
    for i in range(n):
        k = input()
        v = input()
        d[k] = v
    return d
d = nhap_dictionary()
new_d = {}
for k in d:
    v = d[k]
    new_d[v] = k
print(new_d)
# Out:
# {'kien': '2', 'k': '3', 'f': '4', 'g': '5'}

# %% [markdown]
# ## W6A14 [Giao của hai danh sách]
# Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các
# phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các
# phần tử chung đó, không trùng lặp.

# %%
list1 = set(map(int, input().split()))
list2 = set(map(int, input().split()))
ket_qua = list(list1 & list2)
print(ket_qua)

# %% [markdown]
# ## W6A15 [Lọc dictionary theo giá trị]
# Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số
# nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp
# key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary
# mới.

# %%
def nhap_dict():
    d = {}
    n = int(input())
    for i in range(n):
        k = input()
        v = int(input())
        d[k] = v
    return d
d = nhap_dict()
k = int(input())
new_d = {}
for key, value in d.items():
    if value > k:
        new_d[key] = value
print(new_d)
# Out:
# {'q': 3, 'ư': 4}
